# %% [markdown]
# # 载入train文件

# %%
import pandas as pd
import numpy as np

# %%
# %%time
root = "/Users/a117/Desktop/kaggle/data-science-bowl-2019/data/"
train = pd.read_csv(root + "train.csv")
# Out:
# CPU times: user 54.1 s, sys: 45.3 s, total: 1min 39s
# Wall time: 2min 21s

# %%
# Function to reduce DF size

def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if (c_min > np.iinfo(np.int8).min) and  \
                        (c_max < np.iinfo(np.int8).max):
                    df[col] = df[col].astype(np.int8)

                elif (c_min > np.iinfo(np.int16).min) and \
                        (c_max < np.iinfo(np.int16).max):
                    df[col] = df[col].astype(np.int16)

                elif (c_min > np.iinfo(np.int32).min) and \
                        (c_max < np.iinfo(np.int32).max):
                    df[col] = df[col].astype(np.int32)

                elif (c_min > np.iinfo(np.int64).min) and \
                        (c_max < np.iinfo(np.int64).max):
                    df[col] = df[col].astype(np.int64)

            else:
                if (c_min > np.finfo(np.float16).min) and \
                        (c_max < np.finfo(np.float16).max):
                    df[col] = df[col].astype(np.float16)

                elif (c_min > np.finfo(np.float32).min) and \
                        (c_max < np.finfo(np.float32).max):
                    df[col] = df[col].astype(np.float32)

                elif (c_min > np.finfo(np.float64).min) and \
                        (c_max < np.finfo(np.float64).max):
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum() / 1024**2

    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% '
                      'reduction)'.format(
                        end_mem, 100 * (start_mem - end_mem) / start_mem))

    return df

# %%
# 减少内存使用
train = reduce_mem_usage(train)
# Out:
# Mem. usage decreased to 778.73 Mb (18.2% reduction)

# %% [markdown]
# # 清洗函数

# %%
def choose_4100or4110assessment(df, new_df):
    for index, row in df.iterrows():
        if row['event_code'] == 4100 or row['event_code'] == 4110:
            if row['type'] == 'Assessment':
                new_df = new_df.append(row)

    return new_df

# %%
def delete_4100_bird(df):
    delete_index = []
    for index, row in df.iterrows():
        if row['title'].startswith('Bird') and row['event_code'] == 4100:
            delete_index.append(index)

    return df.drop(index=delete_index)

# %%
def clean_train(df, new_df):
    for index, row in df.iterrows():
        if row['event_code'] == 4100 and row['title'].startswith(('Cart', 'Cauldron', 'Chest', 'Mushroom')):
            new_df = new_df.append(row)
        elif row['event_code'] == 4110 and row['title'].startswith('Bird'):
            new_df = new_df.append(row)
    
    return new_df

# %% [markdown]
# # 先用前10000个数据做样本

# %%
train_example = train[:10000]

train_columns = train.columns

train_example_4100or4110assessment = pd.DataFrame(columns=train_columns)
train_example_test = pd.DataFrame(columns=train_columns)

# %%
# %%time
train_example_4100or4110assessment = choose_4100or4110assessment(train_example, train_4100or4110assessment)
train_example_4100or4110assessment = delete_4100_bird(train_example_4100or4110assessment)

len(train_example_4100or4110assessment)
# Out:
# CPU times: user 1.53 s, sys: 12.5 ms, total: 1.55 s
# Wall time: 1.56 s
# 24

# %%
# %%time
train_example_test = clean_train(train_example, train_example_test)
len(train_example_test)
# Out:
# CPU times: user 1.44 s, sys: 7.13 ms, total: 1.45 s
# Wall time: 1.47 s
# 24

# %% [markdown]
# # 整体

# %%
train_4100or4110assessment = pd.DataFrame(columns=train_columns)

# %%
# %%time
train_4100or4110assessment = clean_train(train, train_4100or4110assessment)

# filename = '/Users/a117/Desktop/kaggle/data-science-bowl-2019/data/' \
#            'train_4100or4110assessment.csv'
# train_4100or4110assessment.to_csv(path_or_buf=filename)
# Out:
# CPU times: user 36min 46s, sys: 57.3 s, total: 37min 43s
# Wall time: 38min 13s

# %%
len(train_4100or4110assessment)
# Out:
# 41549

# %% [markdown]
# # 增加True和False列

# %%
# %%time
root = "/Users/a117/Desktop/kaggle/data-science-bowl-2019/data/"
train_assessment = pd.read_csv(root + "train_4100or4110assessment.csv")
# Out:
# CPU times: user 157 ms, sys: 29.7 ms, total: 187 ms
# Wall time: 200 ms

# %%
train_assessment.head()
# Out:
#    Unnamed: 0  event_id      game_session                 timestamp  \
# 0        2228  25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 1        2709  17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 2        2715  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 3        2720  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 4        2725  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
#
#                                           event_data installation_id  \
# 0  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 1  {"correct":false,"caterpillars":[11,8,3],"even...        0006a69f
# 2  {"correct":false,"caterpillars":[11,8,11],"eve...        0006a69f
# 3  {"correct":false,"caterpillars":[11,8,5],"even...        0006a69f
# 4  {"correct":false,"caterpillars":[11,8,7],"even...        0006a69f
#
#    event_count  event_code  game_time                         title  \
# 0           44        4100      31011  Mushroom Sorter (Assessment)
# 1           29        4110      35771    Bird Measurer (Assessment)
# 2           35        4110      42805    Bird Measurer (Assessment)
# 3           40        4110      47388    Bird Measurer (Assessment)
# 4           45        4110      50605    Bird Measurer (Assessment)
#
#          type        world
# 0  Assessment  TREETOPCITY
# 1  Assessment  TREETOPCITY
# 2  Assessment  TREETOPCITY
# 3  Assessment  TREETOPCITY
# 4  Assessment  TREETOPCITY

# %%
train_assessment.rename(columns={'Unnamed: 0':'original_index'}, inplace=True)
train_assessment.head()
# Out:
#    original_index  event_id      game_session                 timestamp  \
# 0            2228  25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 1            2709  17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 2            2715  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 3            2720  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 4            2725  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
#
#                                           event_data installation_id  \
# 0  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 1  {"correct":false,"caterpillars":[11,8,3],"even...        0006a69f
# 2  {"correct":false,"caterpillars":[11,8,11],"eve...        0006a69f
# 3  {"correct":false,"caterpillars":[11,8,5],"even...        0006a69f
# 4  {"correct":false,"caterpillars":[11,8,7],"even...        0006a69f
#
#    event_count  event_code  game_time                         title  \
# 0           44        4100      31011  Mushroom Sorter (Assessment)
# 1           29        4110      35771    Bird Measurer (Assessment)
# 2           35        4110      42805    Bird Measurer (Assessment)
# 3           40        4110      47388    Bird Measurer (Assessment)
# 4           45        4110      50605    Bird Measurer (Assessment)
#
#          type        world
# 0  Assessment  TREETOPCITY
# 1  Assessment  TREETOPCITY
# 2  Assessment  TREETOPCITY
# 3  Assessment  TREETOPCITY
# 4  Assessment  TREETOPCITY

# %%
train_assessment.loc[0, 'event_data']
# Out:
# '{"correct":true,"stumps":[1,2,4],"event_count":44,"game_time":31011,"event_code":4100}'

# %%
import json

# %%
json.loads(train_assessment.loc[0, 'event_data'])['correct']
# Out:
# True

# %%
# %%time
for i in train_assessment.index:
    if json.loads(train_assessment.loc[i, 'event_data'])['correct'] is True:
        train_assessment.loc[i, 'True'] = 1
        train_assessment.loc[i, 'False'] = 0
    elif json.loads(train_assessment.loc[i, 'event_data'])['correct'] is False:
        train_assessment.loc[i, 'True'] = 0
        train_assessment.loc[i, 'False'] = 1
# Out:
# CPU times: user 48.7 s, sys: 380 ms, total: 49.1 s
# Wall time: 49.3 s

# %%
train_assessment.head(100)
# Out:
#     original_index  event_id      game_session                 timestamp  \
# 0             2228  25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 1             2709  17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 2             2715  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 3             2720  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 4             2725  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
# ..             ...       ...               ...                       ...
# 95           24428  17113b36  343206b33bfa7941  2019-08-07T13:19:03.648Z
# 96           25424  392e14df  1454d273262f61e3  2019-10-09T20:37:14.348Z
# 97           25461  d122731b  440633fe3ef55b90  2019-10-09T20:39:40.134Z
# 98           25519  93b353f2  8c2d5dff4635d020  2019-10-09T20:42:07.851Z
# 99           25972  d122731b  a01b01d1e22d0446  2019-09-26T20:05:36.361Z
#
#                                            event_data installation_id  \
# 0   {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 1   {"correct":false,"caterpillars":[11,8,3],"even...        0006a69f
# 2   {"correct":false,"caterpillars":[11,8,11],"eve...        0006a69f
# 3   {"correct":false,"caterpillars":[11,8,5],"even...        0006a69f
# 4   {"correct":false,"caterpillars":[11,8,7],"even...        0006a69f
# ..                                                ...             ...
# 95  {"correct":false,"caterpillars":[1,1,1],"event...        004c2091
# 96  {"buckets":[0,0,0],"correct":true,"buckets_pla...        00634433
# 97  {"correct":true,"left":[{"id":"gem08","weight"...        00634433
# 98  {"correct":false,"pillars":[0,0],"event_count"...        00634433
# 99  {"correct":true,"left":[{"id":"gem07","weight"...        00667b88
#
#     event_count  event_code  game_time                         title  \
# 0            44        4100      31011  Mushroom Sorter (Assessment)
# 1            29        4110      35771    Bird Measurer (Assessment)
# 2            35        4110      42805    Bird Measurer (Assessment)
# 3            40        4110      47388    Bird Measurer (Assessment)
# 4            45        4110      50605    Bird Measurer (Assessment)
# ..          ...         ...        ...                           ...
# 95           17        4110      14731    Bird Measurer (Assessment)
# 96           50        4100      51169  Cauldron Filler (Assessment)
# 97           23        4100      23190    Cart Balancer (Assessment)
# 98           53        4100      69258     Chest Sorter (Assessment)
# 99           46        4100      59191    Cart Balancer (Assessment)
#
#           type         world  True  False
# 0   Assessment   TREETOPCITY   1.0    0.0
# 1   Assessment   TREETOPCITY   0.0    1.0
# 2   Assessment   TREETOPCITY   0.0    1.0
# 3   Assessment   TREETOPCITY   0.0    1.0
# 4   Assessment   TREETOPCITY   0.0    1.0
# ..         ...           ...   ...    ...
# 95  Assessment   TREETOPCITY   0.0    1.0
# 96  Assessment     MAGMAPEAK   1.0    0.0
# 97  Assessment  CRYSTALCAVES   1.0    0.0
# 98  Assessment  CRYSTALCAVES   0.0    1.0
# 99  Assessment  CRYSTALCAVES   1.0    0.0
#
# [100 rows x 14 columns]

# %%
# %whos
# Out:
# Variable                             Type         Data/Info
# -----------------------------------------------------------
# a                                    dict         n=5
# choose_4100or4110assessment          function     <function choose_4100or41<...>ssessment at 0x220f87158>
# clean_train                          function     <function clean_train at 0x1806a8268>
# delete_4100_bird                     function     <function delete_4100_bird at 0x10d0e90d0>
# filename                             str          /Users/a117/Desktop/kaggl<...>_4100or4110assessment.csv
# i                                    int          41548
# json                                 module       <module 'json' from '/Lib<...>hon3.7/json/__init__.py'>
# np                                   module       <module 'numpy' from '/Li<...>kages/numpy/__init__.py'>
# pd                                   module       <module 'pandas' from '/L<...>ages/pandas/__init__.py'>
# reduce_mem_usage                     function     <function reduce_mem_usage at 0x10d0ce9d8>
# root                                 str          /Users/a117/Desktop/kaggl<...>a-science-bowl-2019/data/
# train                                DataFrame              event_id      g<...>341042 rows x 11 columns]
# train_4100or4110                     DataFrame    Empty DataFrame\nColumns:<...>, type, world]\nIndex: []
# train_4100or4110assessment           DataFrame              event_id      g<...>[41549 rows x 11 columns]
# train_assessment                     DataFrame           original_index  ev<...>[41549 rows x 14 columns]
# train_asssessment                    DataFrame           Unnamed: 0  event_<...>[41549 rows x 12 columns]
# train_columns                        Index        Index(['event_id', 'game_<...>],\n      dtype='object')
# train_example                        DataFrame          event_id      game_<...>[10000 rows x 11 columns]
# train_example_4100or4110assessment   DataFrame          event_id      game_<...>Assessment  TREETOPCITY
# train_example_test                   DataFrame          event_id      game_<...>Assessment  TREETOPCITY
